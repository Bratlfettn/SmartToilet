# %%
import os
import random
import time
from datetime import datetime
import pandas as pd

# Zielverzeichnis
output_dir = "sensor_data/csv"
os.makedirs(output_dir, exist_ok=True)

# Funktion zur Generierung zufälliger Lichtmesswerte
def generate_light_data(sensor_id=4):
    dt_now = datetime.now().isoformat()
    return {
        "sensor_id": sensor_id,
        "timestamp": dt_now,
        "light_level_lux": round(random.uniform(0, 1000), 2),  # 0–1000 Lux realistisch für Innenräume
        "day_of_week": random.choice([
            "monday", "tuesday", "wednesday",
            "thursday", "friday", "saturday", "sunday"
        ])
    }

# Benutzerdefinierte Anzahl
num_iterations = int(input("Enter number of light sensor readings to generate: "))

# Daten generieren
light_readings = []
for i in range(num_iterations):
    light_data = generate_light_data()
    print(light_data)
    light_readings.append(light_data)
    time.sleep(1)

    # Optional: Duplikat bei jedem 3. Eintrag
    if i % 3 == 0 and i != 0:
        light_readings.append(light_data)
        print(light_data)

# DataFrame erstellen
df = pd.DataFrame(light_readings)

# Duplikate entfernen
df = df.drop_duplicates()

# Fehlende Werte entfernen (falls nötig)
df = df.dropna()

# CSV speichern
csv_path = os.path.join(output_dir, "light_sensor.csv")
df.to_csv(csv_path, index=False)
print(f"Saved light sensor data to CSV: {csv_path}")
# Out:
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.939394', 'light_level_lux': 452.37, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.940678', 'light_level_lux': 196.41, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.942330', 'light_level_lux': 257.64, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.944005', 'light_level_lux': 89.18, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.944005', 'light_level_lux': 89.18, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.945690', 'light_level_lux': 680.05, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.947385', 'light_level_lux': 781.12, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.949044', 'light_level_lux': 884.12, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.949044', 'light_level_lux': 884.12, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.950689', 'light_level_lux': 715.32, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.952278', 'light_level_lux': 341.07, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.953930', 'light_level_lux': 721.32, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.953930', 'light_level_lux': 721.32, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.955679', 'light_level_lux': 209.73, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.957288', 'light_level_lux': 380.65, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.958888', 'light_level_lux': 625.49, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.958888', 'light_level_lux': 625.49, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.960508', 'light_level_lux': 444.33, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.962098', 'light_level_lux': 707.07, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.963744', 'light_level_lux': 202.6, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.963744', 'light_level_lux': 202.6, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.965322', 'light_level_lux': 363.18, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.966910', 'light_level_lux': 829.94, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.968506', 'light_level_lux': 986.43, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.968506', 'light_level_lux': 986.43, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.970048', 'light_level_lux': 138.79, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.971362', 'light_level_lux': 85.83, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.973163', 'light_level_lux': 814.19, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.973163', 'light_level_lux': 814.19, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.974833', 'light_level_lux': 915.56, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.976461', 'light_level_lux': 489.1, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.978104', 'light_level_lux': 464.33, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.978104', 'light_level_lux': 464.33, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.980250', 'light_level_lux': 243.71, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.981765', 'light_level_lux': 206.82, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.983309', 'light_level_lux': 61.27, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.983309', 'light_level_lux': 61.27, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.985010', 'light_level_lux': 195.85, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.986318', 'light_level_lux': 279.85, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.987665', 'light_level_lux': 136.91, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.987665', 'light_level_lux': 136.91, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.989534', 'light_level_lux': 905.29, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.991385', 'light_level_lux': 666.1, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.992869', 'light_level_lux': 723.8, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.992869', 'light_level_lux': 723.8, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.995034', 'light_level_lux': 579.32, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.996661', 'light_level_lux': 166.63, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.997903', 'light_level_lux': 427.02, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.997903', 'light_level_lux': 427.02, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:10.999592', 'light_level_lux': 76.81, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.001205', 'light_level_lux': 201.24, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.002968', 'light_level_lux': 956.39, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.002968', 'light_level_lux': 956.39, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.004669', 'light_level_lux': 919.48, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.006331', 'light_level_lux': 974.48, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.007817', 'light_level_lux': 640.41, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.007817', 'light_level_lux': 640.41, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.009383', 'light_level_lux': 383.55, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.010945', 'light_level_lux': 425.06, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.012715', 'light_level_lux': 579.53, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.012715', 'light_level_lux': 579.53, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.014597', 'light_level_lux': 383.9, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.016277', 'light_level_lux': 190.92, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.017990', 'light_level_lux': 400.42, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.017990', 'light_level_lux': 400.42, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.020018', 'light_level_lux': 242.19, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.021291', 'light_level_lux': 15.81, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.023168', 'light_level_lux': 604.95, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.023168', 'light_level_lux': 604.95, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.024591', 'light_level_lux': 966.29, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.026531', 'light_level_lux': 78.17, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.027925', 'light_level_lux': 953.2, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.027925', 'light_level_lux': 953.2, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.029454', 'light_level_lux': 121.14, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.030622', 'light_level_lux': 210.51, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.032251', 'light_level_lux': 300.21, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.032251', 'light_level_lux': 300.21, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.033990', 'light_level_lux': 417.35, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.035640', 'light_level_lux': 83.0, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.037236', 'light_level_lux': 564.31, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.037236', 'light_level_lux': 564.31, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.039059', 'light_level_lux': 378.34, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.040713', 'light_level_lux': 956.72, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.042720', 'light_level_lux': 217.82, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.042720', 'light_level_lux': 217.82, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.044088', 'light_level_lux': 831.71, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.045874', 'light_level_lux': 217.77, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.047254', 'light_level_lux': 449.8, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.047254', 'light_level_lux': 449.8, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.048562', 'light_level_lux': 665.64, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.050222', 'light_level_lux': 88.49, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.051843', 'light_level_lux': 64.75, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.051843', 'light_level_lux': 64.75, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.053656', 'light_level_lux': 461.28, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.055049', 'light_level_lux': 888.6, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.056469', 'light_level_lux': 924.32, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.056469', 'light_level_lux': 924.32, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.058104', 'light_level_lux': 843.61, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.059772', 'light_level_lux': 885.22, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.061250', 'light_level_lux': 981.23, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.061250', 'light_level_lux': 981.23, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.063154', 'light_level_lux': 898.6, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.064281', 'light_level_lux': 760.21, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.065949', 'light_level_lux': 794.1, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.065949', 'light_level_lux': 794.1, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.067641', 'light_level_lux': 307.01, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.069452', 'light_level_lux': 385.45, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.070842', 'light_level_lux': 753.98, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.070842', 'light_level_lux': 753.98, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.072727', 'light_level_lux': 60.65, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.073900', 'light_level_lux': 172.02, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.075586', 'light_level_lux': 468.27, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.075586', 'light_level_lux': 468.27, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.077264', 'light_level_lux': 906.82, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.078882', 'light_level_lux': 192.32, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.080513', 'light_level_lux': 330.42, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.080513', 'light_level_lux': 330.42, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.082215', 'light_level_lux': 794.92, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.083834', 'light_level_lux': 865.8, 'day_of_week': 'wednesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.085474', 'light_level_lux': 106.41, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.085474', 'light_level_lux': 106.41, 'day_of_week': 'tuesday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.087272', 'light_level_lux': 248.05, 'day_of_week': 'sunday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.089211', 'light_level_lux': 506.95, 'day_of_week': 'monday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.090408', 'light_level_lux': 812.44, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.090408', 'light_level_lux': 812.44, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.092174', 'light_level_lux': 6.14, 'day_of_week': 'friday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.094054', 'light_level_lux': 191.18, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.095848', 'light_level_lux': 295.95, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.095848', 'light_level_lux': 295.95, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.097269', 'light_level_lux': 461.65, 'day_of_week': 'thursday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.099161', 'light_level_lux': 141.3, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.100711', 'light_level_lux': 422.73, 'day_of_week': 'saturday'}
# {'sensor_id': 4, 'timestamp': '2025-06-02T11:57:11.100711', 'light_level_lux': 422.73, 'day_of_week': 'saturday'}
# Saved light sensor data to CSV: sensor_data/csv\light_sensor.csv
