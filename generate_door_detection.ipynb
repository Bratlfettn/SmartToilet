# %%
import os
import random
import time
from datetime import datetime
import pandas as pd

# Create output directory
output_dir = "sensor_data/csv"
os.makedirs(output_dir, exist_ok=True)

# Funktion zur Generierung zufälliger Türkontakt-Daten
def generate_contact_switch_data(sensor_id=1):
    dt_now = datetime.now().isoformat()
    dt = datetime.fromisoformat(dt_now)
    return {
        "sensor_id": sensor_id,
        "timestamp": dt_now,
        "door_closed": random.choice([True, False]) if random.random() > 0.1 else None,
        "day_of_week": random.choice(["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"])  #str(dt.strftime("%A")).lower() für eine "echte" anwendung
    }

# User input für Anzahl an Datensätzen
num_iterations = int(input("Enter number of door contact readings to generate: "))

# Daten generieren
contacts = []
for i in range(num_iterations):
    contact_data = generate_contact_switch_data()
    print(contact_data)
    contacts.append(contact_data)
    time.sleep(1)

    # Optional: Duplikat bei jedem 3. Eintrag hinzufügen
    if i % 3 == 0 and i != 0:
        contacts.append(contact_data)
        print(contact_data)

# In DataFrame umwandeln
df = pd.DataFrame(contacts)

# Duplikate entfernen
df = df.drop_duplicates()

# Fehlende Werte entfernen
missing_values = df.isnull().sum()
if missing_values.sum() > 0:
    missing_columns = missing_values[missing_values > 0].index.tolist()
    print("\nColumns with missing values:", missing_columns)
    df = df.dropna()
    print("\nDropped rows with missing values.")

# CSV-Datei speichern
csv_path = os.path.join(output_dir, "door_contact.csv")
df.to_csv(csv_path, index=False)
print(f"Saved door contact data to CSV: {csv_path}")
# Out:
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.453746', 'door_closed': False, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.455021', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.456654', 'door_closed': True, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.458286', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.458286', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.459958', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.461587', 'door_closed': False, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.463314', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.463314', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.465055', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.466738', 'door_closed': True, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.468212', 'door_closed': True, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.468212', 'door_closed': True, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.469957', 'door_closed': True, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.471453', 'door_closed': True, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.473155', 'door_closed': False, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.473155', 'door_closed': False, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.474967', 'door_closed': False, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.476607', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.478277', 'door_closed': True, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.478277', 'door_closed': True, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.479864', 'door_closed': True, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.481594', 'door_closed': False, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.483374', 'door_closed': None, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.483374', 'door_closed': None, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.485116', 'door_closed': True, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.486891', 'door_closed': True, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.488650', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.488650', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.490507', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.492136', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.493781', 'door_closed': False, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.493781', 'door_closed': False, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.495493', 'door_closed': True, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.497105', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.498933', 'door_closed': True, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.498933', 'door_closed': True, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.500289', 'door_closed': True, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.502106', 'door_closed': False, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.503403', 'door_closed': False, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.503403', 'door_closed': False, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.505343', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.506714', 'door_closed': False, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.508239', 'door_closed': None, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.508239', 'door_closed': None, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.509943', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.511182', 'door_closed': True, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.512625', 'door_closed': False, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.512625', 'door_closed': False, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.514678', 'door_closed': True, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.515849', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.517590', 'door_closed': True, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.517590', 'door_closed': True, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.519652', 'door_closed': True, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.520825', 'door_closed': False, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.522519', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.522519', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.524207', 'door_closed': False, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.525826', 'door_closed': False, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.527439', 'door_closed': False, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.527439', 'door_closed': False, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.529137', 'door_closed': False, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.530872', 'door_closed': False, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.532511', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.532511', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.534654', 'door_closed': False, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.535928', 'door_closed': True, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.537271', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.537271', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.539120', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.540791', 'door_closed': False, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.542725', 'door_closed': None, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.542725', 'door_closed': None, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.544174', 'door_closed': True, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.545870', 'door_closed': False, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.547170', 'door_closed': True, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.547170', 'door_closed': True, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.548527', 'door_closed': True, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.550154', 'door_closed': True, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.552023', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.552023', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.553978', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.555129', 'door_closed': False, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.557030', 'door_closed': None, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.557030', 'door_closed': None, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.558618', 'door_closed': False, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.560045', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.562078', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.562078', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.563789', 'door_closed': True, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.565276', 'door_closed': True, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.567194', 'door_closed': None, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.567194', 'door_closed': None, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.569276', 'door_closed': False, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.570527', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.572385', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.572385', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.574013', 'door_closed': False, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.575481', 'door_closed': True, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.577386', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.577386', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.578819', 'door_closed': False, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.580651', 'door_closed': False, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.582465', 'door_closed': False, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.582465', 'door_closed': False, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.584482', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.585737', 'door_closed': True, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.587011', 'door_closed': True, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.587011', 'door_closed': True, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.588611', 'door_closed': None, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.590112', 'door_closed': False, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.591809', 'door_closed': False, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.591809', 'door_closed': False, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.593552', 'door_closed': False, 'day_of_week': 'friday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.594772', 'door_closed': True, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.596483', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.596483', 'door_closed': False, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.598333', 'door_closed': True, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.600049', 'door_closed': False, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.602055', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.602055', 'door_closed': True, 'day_of_week': 'thursday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.603412', 'door_closed': None, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.605070', 'door_closed': False, 'day_of_week': 'tuesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.606842', 'door_closed': True, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.606842', 'door_closed': True, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.608812', 'door_closed': True, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.610050', 'door_closed': True, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.611729', 'door_closed': False, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.611729', 'door_closed': False, 'day_of_week': 'monday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.613578', 'door_closed': False, 'day_of_week': 'sunday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.615256', 'door_closed': False, 'day_of_week': 'saturday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.616895', 'door_closed': True, 'day_of_week': 'wednesday'}
# {'sensor_id': 1, 'timestamp': '2025-06-02T11:54:59.616895', 'door_closed': True, 'day_of_week': 'wednesday'}
#
# Columns with missing values: ['door_closed']
#
# Dropped rows with missing values.
# Saved door contact data to CSV: sensor_data/csv\door_contact.csv
